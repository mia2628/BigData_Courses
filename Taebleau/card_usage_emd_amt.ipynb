# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("C:/jtp/month_business1.csv", encoding="cp949", low_memory=False)
df
# Out:
#      Unnamed: 0  pt_month                   biz_nm  base_year_month       age  \
# 0             0         1               건강보조식품 소매업        250841343   50480.0
# 1             1         1                  골프장 운영업        202197402   43160.0
# 2             2         1              과실 및 채소 소매업       1157134834  231290.0
# 3             3         1        관광 민예품 및 선물용품 소매업        557790164  105110.0
# 4             4         1     그외 기타 분류안된 오락관련 서비스업         20380801    3400.0
# ..          ...       ...                      ...              ...       ...
# 497         497        12  피자, 햄버거, 샌드위치 및 유사 음식점업        960030484  176800.0
# 498         498        12                  한식 음식점업       1895439904  353240.0
# 499         499        12                      호텔업        226434064   44460.0
# 500         500        12            화장품 및 방향제 소매업        553968340  105130.0
# 501         501        12                 휴양콘도 운영업        235314692   45560.0
#
# ...

# %%
df.tail(5)
# Out:
#      Unnamed: 0  pt_month                   biz_nm  base_year_month       age  \
# 497         497        12  피자, 햄버거, 샌드위치 및 유사 음식점업        960030484  176800.0
# 498         498        12                  한식 음식점업       1895439904  353240.0
# 499         499        12                      호텔업        226434064   44460.0
# 500         500        12            화장품 및 방향제 소매업        553968340  105130.0
# 501         501        12                 휴양콘도 운영업        235314692   45560.0
#
#      user_cnt  use_cnt       use_amt   pt_year
# 497    318915   343174    4914319414   9599734
# 498   2498961  2675745  119420134072  18953272
# 499     46567    53342   18530139493   2264206
# 500     55543    60489    3332289747   5539354
# 501     38538    45624    5497988579   2353007

# %%
df_2 = df[df["pt_month"] == 2]
df_2
# Out:
#     Unnamed: 0  pt_month                   biz_nm  base_year_month       age  \
# 41          41         2               건강보조식품 소매업        247212750   48750.0
# 42          42         2                  골프장 운영업        208656668   44050.0
# 43          43         2              과실 및 채소 소매업       1117378274  222710.0
# 44          44         2        관광 민예품 및 선물용품 소매업        544269194  101520.0
# 45          45         2     그외 기타 분류안된 오락관련 서비스업         23408832    4000.0
# 46          46         2          그외 기타 스포츠시설 운영업         88593278   16690.0
# 47          47         2             그외 기타 종합 소매업        235304832   43960.0
# 48          48         2             기타 갬블링 및 베팅업          1412414       0.0
# 49          49         2             기타 대형 종합 소매업        200189684   36870.0
# 50          50         2             기타 수상오락 서비스업          9689296    1460.0
# 51          51         2              기타 외국식 음식점업        718028416  142070.0
# ...

# %%
df_8 = df[df["pt_month"] == 8]
df_8
# Out:
#      Unnamed: 0  pt_month                   biz_nm  base_year_month       age  \
# 292         292         8               건강보조식품 소매업        239955412   47360.0
# 293         293         8                  골프장 운영업        218960280   45910.0
# 294         294         8              과실 및 채소 소매업       1173514120  232840.0
# 295         295         8        관광 민예품 및 선물용품 소매업        640141076  118810.0
# 296         296         8     그외 기타 분류안된 오락관련 서비스업         32494688    5610.0
# 297         297         8          그외 기타 스포츠시설 운영업        103729612   19860.0
# 298         298         8             그외 기타 종합 소매업        224411396   42440.0
# 299         299         8             기타 갬블링 및 베팅업          1412656       0.0
# 300         300         8             기타 대형 종합 소매업        207659932   37990.0
# 301         301         8             기타 수상오락 서비스업         31081332    4970.0
# 302         302         8              기타 외국식 음식점업        768697872  151000.0
# ...

# %%
df_c1 = pd.concat([df_2,df_8])
df_c1
# Out:
#      Unnamed: 0  pt_month                   biz_nm  base_year_month       age  \
# 41           41         2               건강보조식품 소매업        247212750   48750.0
# 42           42         2                  골프장 운영업        208656668   44050.0
# 43           43         2              과실 및 채소 소매업       1117378274  222710.0
# 44           44         2        관광 민예품 및 선물용품 소매업        544269194  101520.0
# 45           45         2     그외 기타 분류안된 오락관련 서비스업         23408832    4000.0
# ..          ...       ...                      ...              ...       ...
# 329         329         8  피자, 햄버거, 샌드위치 및 유사 음식점업        996941420  185750.0
# 330         330         8                  한식 음식점업       1972893708  366520.0
# 331         331         8                      호텔업        244797604   46550.0
# 332         332         8            화장품 및 방향제 소매업        586042832  110960.0
# 333         333         8                 휴양콘도 운영업        263367340   50240.0
#
# ...

# %%
df_c1.head()
# Out:
#     Unnamed: 0  pt_month                biz_nm  base_year_month       age  \
# 41          41         2            건강보조식품 소매업        247212750   48750.0
# 42          42         2               골프장 운영업        208656668   44050.0
# 43          43         2           과실 및 채소 소매업       1117378274  222710.0
# 44          44         2     관광 민예품 및 선물용품 소매업        544269194  101520.0
# 45          45         2  그외 기타 분류안된 오락관련 서비스업         23408832    4000.0
#
#     user_cnt  use_cnt     use_amt   pt_year
# 41      5485     5716  1527309892   2472103
# 42     50916    54567  8466213901   2086546
# 43     94726   103447  9526419182  11173672
# 44     51679    55596  1852725724   5442638
# 45       416      425    21947000    234086

# %%
df_c1.to_csv("C:/jtp/df_c1.csv", header=True, index=False, encoding="cp949")

# %%
df_g1 = df.groupby('pt_month').get_group(2)
df_g1
# Out:
#     Unnamed: 0  pt_month                   biz_nm  base_year_month       age  \
# 41          41         2               건강보조식품 소매업        247212750   48750.0
# 42          42         2                  골프장 운영업        208656668   44050.0
# 43          43         2              과실 및 채소 소매업       1117378274  222710.0
# 44          44         2        관광 민예품 및 선물용품 소매업        544269194  101520.0
# 45          45         2     그외 기타 분류안된 오락관련 서비스업         23408832    4000.0
# 46          46         2          그외 기타 스포츠시설 운영업         88593278   16690.0
# 47          47         2             그외 기타 종합 소매업        235304832   43960.0
# 48          48         2             기타 갬블링 및 베팅업          1412414       0.0
# 49          49         2             기타 대형 종합 소매업        200189684   36870.0
# 50          50         2             기타 수상오락 서비스업          9689296    1460.0
# 51          51         2              기타 외국식 음식점업        718028416  142070.0
# ...

# %%
df_g2 = df.groupby('pt_month').get_group(8)
df_g2
# Out:
#      Unnamed: 0  pt_month                   biz_nm  base_year_month       age  \
# 292         292         8               건강보조식품 소매업        239955412   47360.0
# 293         293         8                  골프장 운영업        218960280   45910.0
# 294         294         8              과실 및 채소 소매업       1173514120  232840.0
# 295         295         8        관광 민예품 및 선물용품 소매업        640141076  118810.0
# 296         296         8     그외 기타 분류안된 오락관련 서비스업         32494688    5610.0
# 297         297         8          그외 기타 스포츠시설 운영업        103729612   19860.0
# 298         298         8             그외 기타 종합 소매업        224411396   42440.0
# 299         299         8             기타 갬블링 및 베팅업          1412656       0.0
# 300         300         8             기타 대형 종합 소매업        207659932   37990.0
# 301         301         8             기타 수상오락 서비스업         31081332    4970.0
# 302         302         8              기타 외국식 음식점업        768697872  151000.0
# ...

# %%
df_g = pd.concat([df_g1, df_g2])
df_g
# Out:
#      Unnamed: 0  pt_month                   biz_nm  base_year_month       age  \
# 41           41         2               건강보조식품 소매업        247212750   48750.0
# 42           42         2                  골프장 운영업        208656668   44050.0
# 43           43         2              과실 및 채소 소매업       1117378274  222710.0
# 44           44         2        관광 민예품 및 선물용품 소매업        544269194  101520.0
# 45           45         2     그외 기타 분류안된 오락관련 서비스업         23408832    4000.0
# ..          ...       ...                      ...              ...       ...
# 329         329         8  피자, 햄버거, 샌드위치 및 유사 음식점업        996941420  185750.0
# 330         330         8                  한식 음식점업       1972893708  366520.0
# 331         331         8                      호텔업        244797604   46550.0
# 332         332         8            화장품 및 방향제 소매업        586042832  110960.0
# 333         333         8                 휴양콘도 운영업        263367340   50240.0
#
# ...

# %%
df_i1 = df_g.iloc[:,1:3]
df_i1
# Out:
#      pt_month                   biz_nm
# 41          2               건강보조식품 소매업
# 42          2                  골프장 운영업
# 43          2              과실 및 채소 소매업
# 44          2        관광 민예품 및 선물용품 소매업
# 45          2     그외 기타 분류안된 오락관련 서비스업
# ..        ...                      ...
# 329         8  피자, 햄버거, 샌드위치 및 유사 음식점업
# 330         8                  한식 음식점업
# 331         8                      호텔업
# 332         8            화장품 및 방향제 소매업
# 333         8                 휴양콘도 운영업
#
# [84 rows x 2 columns]

# %%
df_i2 = df_g.iloc[:,7:8]
df_i2
# Out:
#           use_amt
# 41     1527309892
# 42     8466213901
# 43     9526419182
# 44     1852725724
# 45       21947000
# ..            ...
# 329    5616780117
# 330  128466561878
# 331   21318437554
# 332    3440428978
# 333    9816823117
#
# [84 rows x 1 columns]

# %%
df_i = pd.concat([df_i1, df_i2])
df_i
# Out:
#      pt_month                biz_nm       use_amt
# 41        2.0            건강보조식품 소매업           NaN
# 42        2.0               골프장 운영업           NaN
# 43        2.0           과실 및 채소 소매업           NaN
# 44        2.0     관광 민예품 및 선물용품 소매업           NaN
# 45        2.0  그외 기타 분류안된 오락관련 서비스업           NaN
# ..        ...                   ...           ...
# 329       NaN                   NaN  5.616780e+09
# 330       NaN                   NaN  1.284666e+11
# 331       NaN                   NaN  2.131844e+10
# 332       NaN                   NaN  3.440429e+09
# 333       NaN                   NaN  9.816823e+09
#
# [168 rows x 3 columns]
